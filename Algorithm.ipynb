# %% [markdown]
# <a href="https://colab.research.google.com/github/s1270144/ShutoH/blob/master/Algorithm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project８
# # Algorithm Assignment

# %% [markdown]
# Contrastive Divergence (CD) algorithm is a standard way to train a RBM model nowadays.

# %% [markdown]
# The contrastive divergence algorithm is a popular approach to training energy- based latent variable models, which has been widely used in many machine learning models such as the restricted Boltzmann machines and deep belief nets.

# %% [markdown]
# The advantages of this approach is clearly visible in a large dataset, when it needs to compute the sum gradient for all data samples which tremendously expensive cost in conventional gradient methods. Thanks to this property, the RBM method is quite suitable for large scale machine learning problem.

# %% [markdown]
# CDn =KL(p0||p∞)−KL(pn||p∞).

# %% [markdown]
# In CD learning, we start the Markov chain at the data distribution p0 and run the chain for a small number n of steps (e.g. n = 1).
#
#   -> This greatly reduces both the computation per gradient step and the variance of the estimated gradient

# %% [markdown]
# CDn learning to mean learning using the exact distribution of the Markov chain after n steps.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Step-by-Step

# %% [markdown]
# 1.   initial value (𝑥0)
# 2.   The values of hidden layer h are sampled for each element using the conditional
# probability p(h =1|v).
#
# 3.   The values of visible layer v are sampled for each element using the conditional probability p(𝑣𝑗=1|h).
# 4.   This can be done for all or some data points, and
# ![スクリーンショット 2022-08-03 22.52.30.png](data:image/png;base64,...)
#
#             Use this as a substitute for the sum excluding the derivative in the second term above.
